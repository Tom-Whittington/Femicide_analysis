# %% [markdown]
# # Dataset Creation

# %%
import pandas as pd
import numpy as np
import requests
import io
import wbgapi as wb
from bs4 import BeautifulSoup
import cache_magic #pip install ipython_cache
# Out:
# %cache magic is now registered in ipython

# %% [markdown]
# # Femicide Data

# %% [markdown]
# ### Femicide data is downloaded from github and loaded as df_fem

# %%
url = 'https://raw.githubusercontent.com/Tom-Whittington/Femicide_analysis/main/processed_data/original_femicide_data.csv'

# %%
# %cache download = requests.get(url).content
# Out:
# loading cached value for variable 'download'. Time since pickling  1 day, 19:43:41.015817

# %%
df_fem = pd.read_csv(io.StringIO(download.decode('utf-8')),
                dtype={'iso3_code' : 'category',
                           'Region' : 'category',
                           'Subregion' : 'category',
                           'country' : 'category',
                           'Indicator' : 'category',
                           'Disaggregation' : 'category',
                           'Gender' : 'category',
                           'Source' : 'category',
                           'Unit' : 'category',
                          'Year' : 'string'})

# %%
df_fem
# Out:
#        Region           Subregion      country iso3_code  \
# 0        Asia       Southern Asia  Afghanistan       AFG
# 1        Asia       Southern Asia  Afghanistan       AFG
# 2        Asia       Southern Asia  Afghanistan       AFG
# 3        Asia       Southern Asia  Afghanistan       AFG
# 4        Asia       Southern Asia  Afghanistan       AFG
# ...       ...                 ...          ...       ...
# 24387  Africa  Sub-Saharan Africa     Zimbabwe       ZWE
# 24388  Africa  Sub-Saharan Africa     Zimbabwe       ZWE
# 24389  Africa  Sub-Saharan Africa     Zimbabwe       ZWE
# 24390  Africa  Sub-Saharan Africa     Zimbabwe       ZWE
# 24391  Africa  Sub-Saharan Africa     Zimbabwe       ZWE
#
#                     Indicator Disaggregation            Gender Source  \
# 0      Homicide: # of victims              -  Total (all ages)    NSO
# 1      Homicide: # of victims              -  Total (all ages)    NSO
# 2      Homicide: # of victims              -  Total (all ages)    NSO
# 3      Homicide: # of victims              -  Total (all ages)    NSO
# 4      Homicide: # of victims              -  Total (all ages)    NSO
# ...                       ...            ...               ...    ...
# 24387  Homicide: # of victims              -  Total (all ages)    WHO
# 24388  Homicide: # of victims              -  Total (all ages)    WHO
# 24389  Homicide: # of victims              -  Total (all ages)    WHO
# 24390  Homicide: # of victims              -  Total (all ages)    WHO
# 24391  Homicide: # of victims              -  Total (all ages)    WHO
#
#                                Unit  Year Value Footnote
# 0                             Count  2009  1115      NaN
# 1      Rate per  100,000 population  2009  3.93      NaN
# 2                             Count  2010   983      NaN
# 3      Rate per  100,000 population  2010  3.37      NaN
# 4                             Count  2011  1231      NaN
# ...                             ...   ...   ...      ...
# 24387  Rate per  100,000 population  2006  8.82      NaN
# 24388                         Count  2010   711      NaN
# 24389  Rate per  100,000 population  2010   5.6      NaN
# 24390                         Count  2012   981      NaN
# 24391  Rate per  100,000 population  2012  7.48      NaN
#
# [24392 rows x 12 columns]

# %%
df_fem.dtypes
# Out:
# Region            category
# Subregion         category
# country           category
# iso3_code         category
# Indicator         category
# Disaggregation    category
# Gender            category
# Source            category
# Unit              category
# Year                string
# Value               object
# Footnote            object
# dtype: object

# %% [markdown]
# ### Columns are renamed

# %%
df_fem.columns = [col.lower() for col in df_fem.columns]
df_fem = df_fem.rename(columns={'iso3_code' : 'iso3'})
df_fem
# Out:
#        region           subregion country iso3               indicator  \
# 24338  Africa  Sub-Saharan Africa  Zambia  ZMB  Homicide: # of victims
# 24339  Africa  Sub-Saharan Africa  Zambia  ZMB  Homicide: # of victims
# 24340  Africa  Sub-Saharan Africa  Zambia  ZMB  Homicide: # of victims
# 24341  Africa  Sub-Saharan Africa  Zambia  ZMB  Homicide: # of victims
# 24342  Africa  Sub-Saharan Africa  Zambia  ZMB  Homicide: # of victims
# 24343  Africa  Sub-Saharan Africa  Zambia  ZMB  Homicide: # of victims
# 24344  Africa  Sub-Saharan Africa  Zambia  ZMB  Homicide: # of victims
# 24345  Africa  Sub-Saharan Africa  Zambia  ZMB  Homicide: # of victims
# 24346  Africa  Sub-Saharan Africa  Zambia  ZMB  Homicide: # of victims
# 24347  Africa  Sub-Saharan Africa  Zambia  ZMB  Homicide: # of victims
# 24348  Africa  Sub-Saharan Africa  Zambia  ZMB  Homicide: # of victims
# 24349  Africa  Sub-Saharan Africa  Zambia  ZMB  Homicide: # of victims
# 24350  Africa  Sub-Saharan Africa  Zambia  ZMB  Homicide: # of victims
# 24351  Africa  Sub-Saharan Africa  Zambia  ZMB  Homicide: # of victims
# 24352  Africa  Sub-Saharan Africa  Zambia  ZMB  Homicide: # of victims
# 24353  Africa  Sub-Saharan Africa  Zambia  ZMB  Homicide: # of victims
# 24354  Africa  Sub-Saharan Africa  Zambia  ZMB  Homicide: # of victims
# 24355  Africa  Sub-Saharan Africa  Zambia  ZMB  Homicide: # of victims
# 24356  Africa  Sub-Saharan Africa  Zambia  ZMB  Homicide: # of victims
# 24357  Africa  Sub-Saharan Africa  Zambia  ZMB  Homicide: # of victims
# 24358  Africa  Sub-Saharan Africa  Zambia  ZMB  Homicide: # of victims
# 24359  Africa  Sub-Saharan Africa  Zambia  ZMB  Homicide: # of victims
# 24360  Africa  Sub-Saharan Africa  Zambia  ZMB  Homicide: # of victims
# 24361  Africa  Sub-Saharan Africa  Zambia  ZMB  Homicide: # of victims
# 24362  Africa  Sub-Saharan Africa  Zambia  ZMB  Homicide: # of victims
# 24363  Africa  Sub-Saharan Africa  Zambia  ZMB  Homicide: # of victims
# 24364  Africa  Sub-Saharan Africa  Zambia  ZMB  Homicide: # of victims
# 24365  Africa  Sub-Saharan Africa  Zambia  ZMB  Homicide: # of victims
# 24366  Africa  Sub-Saharan Africa  Zambia  ZMB  Homicide: # of victims
# 24367  Africa  Sub-Saharan Africa  Zambia  ZMB  Homicide: # of victims
# 24368  Africa  Sub-Saharan Africa  Zambia  ZMB  Homicide: # of victims
# 24369  Africa  Sub-Saharan Africa  Zambia  ZMB  Homicide: # of victims
#
#       disaggregation            gender source                          unit  \
# 24338              -  Total (all ages)  UNSDC                         Count
# 24339              -  Total (all ages)  UNSDC  Rate per  100,000 population
# 24340              -  Total (all ages)  UNSDC                         Count
# 24341              -  Total (all ages)  UNSDC  Rate per  100,000 population
# 24342              -  Total (all ages)  UNSDC                         Count
# 24343              -  Total (all ages)  UNSDC  Rate per  100,000 population
# 24344              -  Total (all ages)  UNSDC                         Count
# 24345              -  Total (all ages)  UNSDC  Rate per  100,000 population
# 24346              -  Total (all ages)  UNSDC                         Count
# 24347              -  Total (all ages)  UNSDC  Rate per  100,000 population
# 24348              -  Total (all ages)  UNSDC                         Count
# 24349              -  Total (all ages)  UNSDC  Rate per  100,000 population
# 24350              -  Total (all ages)  UNSDC                         Count
# 24351              -  Total (all ages)  UNSDC  Rate per  100,000 population
# 24352              -  Total (all ages)  UNSDC                         Count
# 24353              -  Total (all ages)  UNSDC  Rate per  100,000 population
# 24354              -  Total (all ages)    WHO                         Count
# 24355              -  Total (all ages)    WHO  Rate per  100,000 population
# 24356              -  Total (all ages)    WHO                         Count
# 24357              -  Total (all ages)    WHO  Rate per  100,000 population
# 24358              -  Total (all ages)    WHO                         Count
# 24359              -  Total (all ages)    WHO  Rate per  100,000 population
# 24360              -  Total (all ages)     NP                         Count
# 24361              -  Total (all ages)     NP  Rate per  100,000 population
# 24362              -  Total (all ages)     NP                         Count
# 24363              -  Total (all ages)     NP  Rate per  100,000 population
# 24364              -  Total (all ages)     NP                         Count
# 24365              -  Total (all ages)     NP  Rate per  100,000 population
# 24366              -  Total (all ages)     NP                         Count
# 24367              -  Total (all ages)     NP  Rate per  100,000 population
# 24368              -  Total (all ages)     NP                         Count
# 24369              -  Total (all ages)     NP  Rate per  100,000 population
#
#        year  value footnote
# 24338  1990    550      NaN
# 24339  1990   6.84      NaN
# 24340  1991    684      NaN
# 24341  1991   8.29      NaN
# 24342  1992    768      NaN
# 24343  1992   9.09      NaN
# 24344  1993    745      NaN
# 24345  1993   8.61      NaN
# 24346  1994    831      NaN
# 24347  1994   9.37      NaN
# 24348  1998    872      NaN
# 24349  1998   8.84      NaN
# 24350  1999   1072      NaN
# 24351  1999  10.57      NaN
# 24352  2000    797      NaN
# 24353  2000   7.65      NaN
# 24354  2008    694      NaN
# 24355  2008    5.4      NaN
# 24356  2009    812      NaN
# 24357  2009   6.14      NaN
# 24358  2010    814      NaN
# 24359  2010   5.98      NaN
# 24360  2011    863      NaN
# 24361  2011   6.15      NaN
# 24362  2012    885      NaN
# 24363  2012   6.12      NaN
# 24364  2013    867      NaN
# 24365  2013   5.81      NaN
# 24366  2014    825      NaN
# 24367  2014   5.36      NaN
# 24368  2015    853      NaN
# 24369  2015   5.37      NaN

# %% [markdown]
# ### Filters out totals and only keeps male and female data

# %%
df_fem = df_fem.loc[(df_fem['gender'] == 'Male') | (df_fem['gender'] == 'Female')]
df_fem
# Out:
#          region                        subregion  \
# 8          Asia                    Southern Asia
# 9          Asia                    Southern Asia
# 10         Asia                    Southern Asia
# 11         Asia                    Southern Asia
# 14         Asia                    Southern Asia
# ...         ...                              ...
# 24293  Americas  Latin America and the Caribbean
# 24372    Africa               Sub-Saharan Africa
# 24373    Africa               Sub-Saharan Africa
# 24374    Africa               Sub-Saharan Africa
# 24375    Africa               Sub-Saharan Africa
#
#                                   country iso3               indicator  \
# 8                             Afghanistan  AFG  Homicide: # of victims
# 9                             Afghanistan  AFG  Homicide: # of victims
# 10                            Afghanistan  AFG  Homicide: # of victims
# 11                            Afghanistan  AFG  Homicide: # of victims
# 14                            Afghanistan  AFG  Homicide: # of victims
# ...                                   ...  ...                     ...
# 24293  Venezuela (Bolivarian Republic of)  VEN  Homicide: # of victims
# 24372                            Zimbabwe  ZWE  Homicide: # of victims
# 24373                            Zimbabwe  ZWE  Homicide: # of victims
# 24374                            Zimbabwe  ZWE  Homicide: # of victims
# 24375                            Zimbabwe  ZWE  Homicide: # of victims
#
#       disaggregation  gender source                          unit  year  \
# 8                  -  Female    NSO                         Count  2015
# 9                  -  Female    NSO  Rate per  100,000 population  2015
# 10                 -    Male    NSO                         Count  2015
# 11                 -    Male    NSO  Rate per  100,000 population  2015
# 14                 -  Female    NSO                         Count  2016
# ...              ...     ...    ...                           ...   ...
# 24293              -    Male    CTS  Rate per  100,000 population  2017
# 24372              -  Female     MD                         Count  1990
# 24373              -  Female     MD  Rate per  100,000 population  1990
# 24374              -    Male     MD                         Count  1990
# 24375              -    Male     MD  Rate per  100,000 population  1990
#
#        value footnote
# 8         93      NaN
# 9       0.56      NaN
# 10      3274      NaN
# 11     18.51      NaN
# 14       101      NaN
# ...      ...      ...
# 24293  93.88      NaN
# 24372    183      NaN
# 24373   3.49      NaN
# 24374    404      NaN
# 24375   7.78      NaN
#
# [14206 rows x 12 columns]

# %% [markdown]
# ### Removes killed by intimate partner disaggregation

# %%
df_fem = df_fem[df_fem['disaggregation'] == '-']
df_fem
# Out:
#          region                        subregion  \
# 8          Asia                    Southern Asia
# 9          Asia                    Southern Asia
# 10         Asia                    Southern Asia
# 11         Asia                    Southern Asia
# 14         Asia                    Southern Asia
# ...         ...                              ...
# 24293  Americas  Latin America and the Caribbean
# 24372    Africa               Sub-Saharan Africa
# 24373    Africa               Sub-Saharan Africa
# 24374    Africa               Sub-Saharan Africa
# 24375    Africa               Sub-Saharan Africa
#
#                                   country iso3               indicator  \
# 8                             Afghanistan  AFG  Homicide: # of victims
# 9                             Afghanistan  AFG  Homicide: # of victims
# 10                            Afghanistan  AFG  Homicide: # of victims
# 11                            Afghanistan  AFG  Homicide: # of victims
# 14                            Afghanistan  AFG  Homicide: # of victims
# ...                                   ...  ...                     ...
# 24293  Venezuela (Bolivarian Republic of)  VEN  Homicide: # of victims
# 24372                            Zimbabwe  ZWE  Homicide: # of victims
# 24373                            Zimbabwe  ZWE  Homicide: # of victims
# 24374                            Zimbabwe  ZWE  Homicide: # of victims
# 24375                            Zimbabwe  ZWE  Homicide: # of victims
#
#       disaggregation  gender source                          unit  year  \
# 8                  -  Female    NSO                         Count  2015
# 9                  -  Female    NSO  Rate per  100,000 population  2015
# 10                 -    Male    NSO                         Count  2015
# 11                 -    Male    NSO  Rate per  100,000 population  2015
# 14                 -  Female    NSO                         Count  2016
# ...              ...     ...    ...                           ...   ...
# 24293              -    Male    CTS  Rate per  100,000 population  2017
# 24372              -  Female     MD                         Count  1990
# 24373              -  Female     MD  Rate per  100,000 population  1990
# 24374              -    Male     MD                         Count  1990
# 24375              -    Male     MD  Rate per  100,000 population  1990
#
#        value footnote
# 8         93      NaN
# 9       0.56      NaN
# 10      3274      NaN
# 11     18.51      NaN
# 14       101      NaN
# ...      ...      ...
# 24293  93.88      NaN
# 24372    183      NaN
# 24373   3.49      NaN
# 24374    404      NaN
# 24375   7.78      NaN
#
# [9430 rows x 12 columns]

# %% [markdown]
# ### Filters out counts and leaves only rate per 100k, sorts values and converts value column to numeric

# %%
df_fem = df_fem[df_fem['unit'] != 'Count']
df_fem = df_fem.sort_values(['year', 'gender', 'iso3'])
df_fem['value'] = pd.to_numeric(df_fem['value'], errors='coerce')
df_fem
# Out:
#          region                        subregion              country iso3  \
# 1193   Americas  Latin America and the Caribbean                Aruba  ABW
# 899        Asia                     Western Asia              Armenia  ARM
# 675    Americas  Latin America and the Caribbean  Antigua and Barbuda  ATG
# 1295    Oceania        Australia and New Zealand            Australia  AUS
# 1561     Europe                   Western Europe              Austria  AUT
# ...         ...                              ...                  ...  ...
# 22001    Europe                  Northern Europe               Sweden  SWE
# 22427      Asia                     Central Asia           Tajikistan  TJK
# 22665   Oceania                        Polynesia                Tonga  TON
# 22845    Africa                  Northern Africa              Tunisia  TUN
# 24137   Oceania                        Melanesia              Vanuatu  VUT
#
#                     indicator disaggregation  gender    source  \
# 1193   Homicide: # of victims              -  Female        MD
# 899    Homicide: # of victims              -  Female     UNECE
# 675    Homicide: # of victims              -  Female        MD
# 1295   Homicide: # of victims              -  Female        MD
# 1561   Homicide: # of victims              -  Female        MD
# ...                       ...            ...     ...       ...
# 22001  Homicide: # of victims              -    Male  External
# 22427  Homicide: # of victims              -    Male       CTS
# 22665  Homicide: # of victims              -    Male  External
# 22845  Homicide: # of victims              -    Male  External
# 24137  Homicide: # of victims              -    Male  External
#
#                                unit  year  value footnote
# 1193   Rate per  100,000 population  1990   0.00      NaN
# 899    Rate per  100,000 population  1990   1.25      NaN
# 675    Rate per  100,000 population  1990   3.10      NaN
# 1295   Rate per  100,000 population  1990   1.62      NaN
# 1561   Rate per  100,000 population  1990   0.99      NaN
# ...                             ...   ...    ...      ...
# 22001  Rate per  100,000 population  2020   1.96      NaN
# 22427  Rate per  100,000 population  2020   1.81      NaN
# 22665  Rate per  100,000 population  2020   3.78      NaN
# 22845  Rate per  100,000 population  2020   7.63      NaN
# 24137  Rate per  100,000 population  2020   0.00      NaN
#
# [4715 rows x 12 columns]

# %% [markdown]
# ### Pivots df, using year and gender as index. Then formats new columns

# %%
df_fem = df_fem.pivot(index='iso3', columns=['year', 'gender'], values='value')
df_fem.columns = ['-'.join(col) for col in df_fem.columns]
df_fem
# Out:
#       1990-Female  1990-Male  1991-Female  1991-Male  1992-Female  1992-Male  \
# iso3
# ABW          0.00       0.00          NaN        NaN          NaN        NaN
# ARM          1.25       9.05         1.64       9.23          NaN        NaN
# ATG          3.10       0.00         6.12       3.26         3.00       3.21
# AUS          1.62       2.79         1.66       2.30         1.34       2.12
# AUT          0.99       1.33         1.16       1.51         1.05       1.44
# ...           ...        ...          ...        ...          ...        ...
# FSM           NaN        NaN          NaN        NaN          NaN        NaN
# SYR           NaN        NaN          NaN        NaN          NaN        NaN
# TUN           NaN        NaN          NaN        NaN          NaN        NaN
# VUT           NaN        NaN          NaN        NaN          NaN        NaN
# NAM           NaN        NaN          NaN        NaN          NaN        NaN
#
#       1993-Female  1993-Male  1994-Female  1994-Male  ...  2016-Female  \
# iso3                                                  ...
# ABW           NaN        NaN          NaN        NaN  ...          NaN
# ARM          3.08      13.31         1.43       8.48  ...         0.90
# ATG          0.00      12.64         2.86      12.42  ...         4.08
# AUS          1.34       2.45         1.28       2.32  ...         0.66
# AUT          0.85       1.19         1.27       0.93  ...         0.70
# ...           ...        ...          ...        ...  ...          ...
# FSM           NaN        NaN          NaN        NaN  ...          NaN
# SYR           NaN        NaN          NaN        NaN  ...          NaN
# TUN           NaN        NaN          NaN        NaN  ...          NaN
# VUT           NaN        NaN          NaN        NaN  ...          NaN
# NAM           NaN        NaN          NaN        NaN  ...          NaN
#
#       2016-Male  2017-Female  2017-Male  2018-Female  2018-Male  2019-Female  \
# iso3
# ABW         NaN          NaN        NaN          NaN        NaN          NaN
# ARM        5.00         0.71       4.26         0.70       2.81         0.64
# ATG       15.38         4.05      39.14         6.02      19.39         1.99
# AUS        1.22         0.51       1.18         0.67       1.09         0.54
# AUT        0.54         0.82       0.76         0.97       0.96         0.88
# ...         ...          ...        ...          ...        ...          ...
# FSM         NaN          NaN        NaN          NaN        NaN         1.79
# SYR         NaN          NaN        NaN          NaN        NaN         8.77
# TUN         NaN          NaN        NaN          NaN        NaN         1.75
# VUT         NaN          NaN        NaN          NaN        NaN         0.68
# NAM         NaN          NaN        NaN          NaN        NaN          NaN
#
#       2019-Male  2020-Female  2020-Male
# iso3
# ABW         NaN          NaN        NaN
# ARM        4.53         1.02       2.58
# ATG        4.27          NaN        NaN
# AUS        1.24         0.58       1.18
# AUT        0.84         0.81       0.63
# ...         ...          ...        ...
# FSM        0.00          NaN        NaN
# SYR       30.59          NaN        NaN
# TUN        8.07         1.93       7.63
# VUT        0.66         0.66       0.00
# NAM         NaN         6.87      17.29
#
# [150 rows x 62 columns]

# %%
df_fem.isna().sum()
# Out:
# 1990-Female    114
# 1990-Male      114
# 1991-Female    117
# 1991-Male      117
# 1992-Female    115
#               ...
# 2018-Male       60
# 2019-Female     57
# 2019-Male       57
# 2020-Female     86
# 2020-Male       87
# Length: 62, dtype: int64

# %%
df_fem.dtypes
# Out:
# 1990-Female    float64
# 1990-Male      float64
# 1991-Female    float64
# 1991-Male      float64
# 1992-Female    float64
#                 ...
# 2018-Male      float64
# 2019-Female    float64
# 2019-Male      float64
# 2020-Female    float64
# 2020-Male      float64
# Length: 62, dtype: object

# %% [markdown]
# # Economic data

# %% [markdown]
# ## Worldbank data import

# %% [markdown]
# ### Economic data is imported from worldbank API
# 1. NY.GNP.PCAP.CD represents gross national income per capita
#
# 2. SI.POV.GINI represents the gini coefficient of each country
#
# 3. Years 2000-2023 are selected
#
# 4. Labels also returns country code
#
# 5. skipBlanks is turned off so we have a row for each year (easier merging)
#
# 6. each series is added to column
#
# 7. skipAggs returns only countries and not regions/aggregations
#
# 8. Result is cached as can be slow to return

# %%
# %cache df_wb = wb.data.DataFrame(['NY.GNP.PCAP.CD','SI.POV.GINI'], time=range(2000,2023), labels=True, skipBlanks =False, columns='series', skipAggs=True)
# Out:
# loading cached value for variable 'df_wb'. Time since pickling  1:16:47.020425

# %% [markdown]
# ### Index is reset, columns renamed and converted to datetime format. Extra time column is dropped and index is set to country code and year

# %%
df_wb = df_wb.reset_index()

df_wb = df_wb.rename(columns={'economy':'iso3',
                        'Time':'year',
                        'NY.GNP.PCAP.CD':'gnipc',
                        'SI.POV.GINI':'gini',
                        'Country':'country'})

df_wb['year'] = pd.to_datetime(df_wb['year'], format='%Y')

df_wb['gnipc'] = pd.to_numeric(df_wb['gnipc'], errors='coerce')
df_wb['gini'] = pd.to_numeric(df_wb['gini'], errors='coerce')

df_wb = df_wb.drop(columns='time')

df_wb = df_wb.set_index(['iso3', 'year'])
df_wb
# Out:
#                      country   gnipc  gini
# iso3 year
# ZWE  2021-01-01     Zimbabwe  1530.0   NaN
#      2020-01-01     Zimbabwe  1460.0   NaN
#      2019-01-01     Zimbabwe  1450.0  50.3
#      2018-01-01     Zimbabwe  1550.0   NaN
#      2017-01-01     Zimbabwe  1170.0  44.3
# ...                      ...     ...   ...
# AFG  2004-01-01  Afghanistan     NaN   NaN
#      2003-01-01  Afghanistan     NaN   NaN
#      2002-01-01  Afghanistan     NaN   NaN
#      2001-01-01  Afghanistan     NaN   NaN
#      2000-01-01  Afghanistan     NaN   NaN
#
# [4774 rows x 3 columns]

# %%
df_wb.isna().sum()
# Out:
# country       0
# gnipc       539
# gini       3317
# dtype: int64

# %%
df_wb.dtypes
# Out:
# country     object
# gnipc      float64
# gini       float64
# dtype: object

# %% [markdown]
# ## CIA data

# %% [markdown]
# ### Gets webpage from url

# %%
url = 'https://www.cia.gov/the-world-factbook/field/gini-index-coefficient-distribution-of-family-income/country-comparison'

# %cache r = requests.get(url)

soup = BeautifulSoup(r.text, 'lxml')
# Out:
# loading cached value for variable 'r'. Time since pickling  1 day, 19:43:17.842068

# %% [markdown]
# ### Finds first table on page, extracts headers from first row and then loops over table and creates dataframe from values

# %%
table = soup.findAll('table')[0]

headers = [x.text for x in table.findChildren('th')[1:]]

row_list = headers
table_list = []
for row in table.findChildren('tr'):

    for cell in row.findChildren('td')[1:]:
        row_list.append(cell.text)
    table_list.append(row_list)
    row_list = []

df_cia = pd.DataFrame(table_list)

# %% [markdown]
# ### Adds gini label to first row and then promotes first row to headers

# %%
df_cia.iloc[0,1]='gini'

df_cia.columns= df_cia.iloc[0,:]

df_cia = df_cia[1:]

df_cia
# Out:
# 0                     Country  gini Date of Information
# 1                South Africa  63.0           2014 est.
# 2                     Namibia  59.1           2015 est.
# 3                      Zambia  57.1           2015 est.
# 4    Central African Republic  56.2           2008 est.
# 5                    Eswatini  54.6           2016 est.
# ..                        ...   ...                 ...
# 173                  Slovakia  25.2           2016 est.
# 174                   Belarus  24.4           2020 est.
# 175                  Slovenia  24.2           2017 est.
# 176             Faroe Islands  22.7           2013 est.
# 177                    Jersey   0.3           2014 est.
#
# [177 rows x 3 columns]

# %% [markdown]
# ### iso3 codes are generated for CIA data set by the worldbank api, Nas are dropped, year and iso3 set as index ready for filling in blanks

# %%
df_cia['iso3'] = wb.economy.coder(df_cia['Country'])
df_cia = df_cia.dropna(subset='iso3')
df_cia['year'] =df_cia['Date of Information'].str[:4]
df_cia = df_cia[['iso3', 'year', 'Country', 'gini']]
df_cia['year'] = pd.to_datetime(df_cia['year'], format='%Y')
df_cia = df_cia.set_index(['iso3', 'year'])
df_cia
# Out:
# /tmp/ipykernel_11290/25053258.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cia['year'] =df_cia['Date of Information'].str[:4]
# 0                                 Country  gini
# iso3 year
# ZAF  2014-01-01              South Africa  63.0
# NAM  2015-01-01                   Namibia  59.1
# ZMB  2015-01-01                    Zambia  57.1
# CAF  2008-01-01  Central African Republic  56.2
# SWZ  2016-01-01                  Eswatini  54.6
# ...                                   ...   ...
# ARM  2020-01-01                   Armenia  25.2
# SVK  2016-01-01                  Slovakia  25.2
# BLR  2020-01-01                   Belarus  24.4
# SVN  2017-01-01                  Slovenia  24.2
# FRO  2013-01-01             Faroe Islands  22.7
#
# [173 rows x 2 columns]

# %%
df_wb.isna().sum()
# Out:
# country       0
# gnipc       539
# gini       3317
# dtype: int64

# %% [markdown]
# ### Fills in any empty cells in wb dataset with values from cia dataset ~17 extra countries. gini column set back to float

# %%
df_eco = df_wb.copy()

df_eco['gini'] = df_eco['gini'].fillna(df_cia['gini'])

df_eco = df_eco.sort_index()

df_eco['gini'] =df_eco['gini'].astype('float64')

df_eco
# Out:
#                   country    gnipc  gini
# iso3 year
# ABW  2000-01-01     Aruba  20390.0   NaN
#      2001-01-01     Aruba  20510.0   NaN
#      2002-01-01     Aruba  19290.0   NaN
#      2003-01-01     Aruba  21120.0   NaN
#      2004-01-01     Aruba  24010.0   NaN
# ...                   ...      ...   ...
# ZWE  2017-01-01  Zimbabwe   1170.0  44.3
#      2018-01-01  Zimbabwe   1550.0   NaN
#      2019-01-01  Zimbabwe   1450.0  50.3
#      2020-01-01  Zimbabwe   1460.0   NaN
#      2021-01-01  Zimbabwe   1530.0   NaN
#
# [4774 rows x 3 columns]

# %%
df_eco.isna().sum()
# Out:
# country       0
# gnipc       539
# gini       3300
# dtype: int64

# %%
df_eco.dtypes
# Out:
# country     object
# gnipc      float64
# gini       float64
# dtype: object

# %%
df_eco.to_csv(r'processed_data/wb_cia_economic_all_rows.csv')

# %% [markdown]
# ## Dichotamising eco data

# %% [markdown]
# ### df is split between gini and gnipc dataframes for dichotamising

# %%
df_eco = df_eco.reset_index()
df_gini = df_eco[['iso3', 'year', 'country', 'gini']]
df_gnipc = df_eco[['iso3', 'year', 'country', 'gnipc']]

# %% [markdown]
# ### Nas are dropped, results are grouped by iso3 and returns last year that there is a value for gnipc (latest year that there is data for. Columns are then renamed

# %%
df_gnipc = df_gnipc.dropna(subset='gnipc')
df_gnipc = df_gnipc.sort_values('year').groupby('iso3').last()
df_gnipc = df_gnipc.rename(columns={'year' : 'gnipc_year'})
df_gnipc
# Out:
#      gnipc_year       country    gnipc
# iso3
# ABW  2021-01-01         Aruba  29390.0
# AFG  2021-01-01   Afghanistan    390.0
# AGO  2021-01-01        Angola   1710.0
# ALB  2021-01-01       Albania   6110.0
# AND  2019-01-01       Andorra  46530.0
# ...         ...           ...      ...
# XKX  2021-01-01        Kosovo   5130.0
# YEM  2018-01-01   Yemen, Rep.    840.0
# ZAF  2021-01-01  South Africa   6530.0
# ZMB  2021-01-01        Zambia   1030.0
# ZWE  2021-01-01      Zimbabwe   1530.0
#
# [207 rows x 3 columns]

# %% [markdown]
# ### Nas are dropped, results are grouped by iso3 and returns last year that there is a gini value for (latest year that there is data for. Columns are then renamed

# %%
df_gini = df_gini.dropna(subset='gini')
df_gini = df_gini.sort_values('year').groupby('iso3').last()
df_gini = df_gini.rename(columns={'year' : 'gini_year'})
df_gini
# Out:
#       gini_year               country  gini
# iso3
# AFG  2008-01-01           Afghanistan  29.4
# AGO  2018-01-01                Angola  51.3
# ALB  2019-01-01               Albania  30.8
# ARE  2018-01-01  United Arab Emirates  26.0
# ARG  2020-01-01             Argentina  42.3
# ...         ...                   ...   ...
# XKX  2017-01-01                Kosovo  29.0
# YEM  2014-01-01           Yemen, Rep.  36.7
# ZAF  2014-01-01          South Africa  63.0
# ZMB  2015-01-01                Zambia  57.1
# ZWE  2019-01-01              Zimbabwe  50.3
#
# [173 rows x 3 columns]

# %% [markdown]
# ### World median gnipc is calculated to be used in dichotamisation

# %%
world_median_gnipc = df_gnipc['gnipc'].median()
world_median_gnipc
# Out:
# 6460.0

# %% [markdown]
# ### World median gini is calculated to be used in dichotamisation

# %%
world_median_gini = df_gini['gini'].median()
world_median_gini
# Out:
# 35.9

# %% [markdown]
# ### If country's gnipc is higher than the world median gnipc then it is classed as high income_level

# %%
df_gnipc['income_level'] = np.where(df_gnipc['gnipc'] > world_median_gnipc, 'high', 'low')
df_gnipc
# Out:
#      gnipc_year       country    gnipc income_level
# iso3
# ABW  2021-01-01         Aruba  29390.0         high
# AFG  2021-01-01   Afghanistan    390.0          low
# AGO  2021-01-01        Angola   1710.0          low
# ALB  2021-01-01       Albania   6110.0          low
# AND  2019-01-01       Andorra  46530.0         high
# ...         ...           ...      ...          ...
# XKX  2021-01-01        Kosovo   5130.0          low
# YEM  2018-01-01   Yemen, Rep.    840.0          low
# ZAF  2021-01-01  South Africa   6530.0         high
# ZMB  2021-01-01        Zambia   1030.0          low
# ZWE  2021-01-01      Zimbabwe   1530.0          low
#
# [207 rows x 4 columns]

# %% [markdown]
# ### If country's gini is higher than the world median gini then it is classed as high inequality_level

# %%
df_gini['inequality_level'] = np.where(df_gini['gini'] > world_median_gini, 'high', 'low')
df_gini
# Out:
#       gini_year               country  gini inequality_level
# iso3
# AFG  2008-01-01           Afghanistan  29.4              low
# AGO  2018-01-01                Angola  51.3             high
# ALB  2019-01-01               Albania  30.8              low
# ARE  2018-01-01  United Arab Emirates  26.0              low
# ARG  2020-01-01             Argentina  42.3             high
# ...         ...                   ...   ...              ...
# XKX  2017-01-01                Kosovo  29.0              low
# YEM  2014-01-01           Yemen, Rep.  36.7             high
# ZAF  2014-01-01          South Africa  63.0             high
# ZMB  2015-01-01                Zambia  57.1             high
# ZWE  2019-01-01              Zimbabwe  50.3             high
#
# [173 rows x 4 columns]

# %% [markdown]
# ### gini and gnipc dataframes are then joined to form the full dichotamised dataframe. Uneeded columns are dropped and columns are renamed

# %%
df_eco_dichot = df_gnipc.merge(df_gini, how='outer', on='iso3')
df_eco_dichot = df_eco_dichot[['country_x', 'income_level', 'inequality_level', 'gnipc', 'gini', 'gnipc_year', 'gini_year' ]]
df_eco_dichot = df_eco_dichot.dropna(subset='country_x')
df_eco_dichot = df_eco_dichot.rename(columns={'country_x' : 'country'})
df_eco_dichot
# Out:
#            country income_level inequality_level    gnipc  gini gnipc_year  \
# iso3
# ABW          Aruba         high              NaN  29390.0   NaN 2021-01-01
# AFG    Afghanistan          low              low    390.0  29.4 2021-01-01
# AGO         Angola          low             high   1710.0  51.3 2021-01-01
# ALB        Albania          low              low   6110.0  30.8 2021-01-01
# AND        Andorra         high              NaN  46530.0   NaN 2019-01-01
# ...            ...          ...              ...      ...   ...        ...
# XKX         Kosovo          low              low   5130.0  29.0 2021-01-01
# YEM    Yemen, Rep.          low             high    840.0  36.7 2018-01-01
# ZAF   South Africa         high             high   6530.0  63.0 2021-01-01
# ZMB         Zambia          low             high   1030.0  57.1 2021-01-01
# ZWE       Zimbabwe          low             high   1530.0  50.3 2021-01-01
#
#       gini_year
# iso3
# ABW         NaT
# AFG  2008-01-01
# AGO  2018-01-01
# ALB  2019-01-01
# AND         NaT
# ...         ...
# XKX  2017-01-01
# YEM  2014-01-01
# ZAF  2014-01-01
# ZMB  2015-01-01
# ZWE  2019-01-01
#
# [207 rows x 7 columns]

# %%
df_eco_dichot.isna().sum()
# Out:
# country              0
# income_level         0
# inequality_level    35
# gnipc                0
# gini                35
# gnipc_year           0
# gini_year           35
# dtype: int64

# %%
df_eco_dichot.dtypes
# Out:
# country                     object
# income_level                object
# inequality_level            object
# gnipc                      float64
# gini                       float64
# gnipc_year          datetime64[ns]
# gini_year           datetime64[ns]
# dtype: object

# %%
df_eco_dichot.to_csv(r'processed_data/eco_dichot.csv')

# %% [markdown]
# # Merging

# %% [markdown]
# ### The dichotamised economic dataframe is merged with the femicide dataframe on the shared iso3 index

# %%
df = df_eco_dichot.merge(df_fem, how='left', left_index=True, right_index=True)
df
# Out:
#            country income_level inequality_level    gnipc  gini gnipc_year  \
# iso3
# ABW          Aruba         high              NaN  29390.0   NaN 2021-01-01
# AFG    Afghanistan          low              low    390.0  29.4 2021-01-01
# AGO         Angola          low             high   1710.0  51.3 2021-01-01
# ALB        Albania          low              low   6110.0  30.8 2021-01-01
# AND        Andorra         high              NaN  46530.0   NaN 2019-01-01
# ...            ...          ...              ...      ...   ...        ...
# XKX         Kosovo          low              low   5130.0  29.0 2021-01-01
# YEM    Yemen, Rep.          low             high    840.0  36.7 2018-01-01
# ZAF   South Africa         high             high   6530.0  63.0 2021-01-01
# ZMB         Zambia          low             high   1030.0  57.1 2021-01-01
# ZWE       Zimbabwe          low             high   1530.0  50.3 2021-01-01
#
#       gini_year  1990-Female  1990-Male  1991-Female  ...  2016-Female  \
# iso3                                                  ...
# ABW         NaT         0.00       0.00          NaN  ...          NaN
# AFG  2008-01-01          NaN        NaN          NaN  ...         0.59
# AGO  2018-01-01          NaN        NaN          NaN  ...          NaN
# ALB  2019-01-01          NaN        NaN          NaN  ...         1.20
# AND         NaT          NaN        NaN          NaN  ...          NaN
# ...         ...          ...        ...          ...  ...          ...
# XKX  2017-01-01          NaN        NaN          NaN  ...          NaN
# YEM  2014-01-01          NaN        NaN          NaN  ...          NaN
# ZAF  2014-01-01          NaN        NaN          NaN  ...         9.27
# ZMB  2015-01-01          NaN        NaN          NaN  ...          NaN
# ZWE  2019-01-01         3.49       7.78          NaN  ...          NaN
#
#       2016-Male  2017-Female  2017-Male  2018-Female  2018-Male  2019-Female  \
# iso3
# ABW         NaN          NaN        NaN          NaN        NaN          NaN
# AFG       12.19         0.75      12.28         0.85      12.16          NaN
# AGO         NaN          NaN        NaN          NaN        NaN          NaN
# ALB        4.22         0.92       3.06         1.06       3.47         0.92
# AND         NaN          NaN        NaN          NaN        NaN          NaN
# ...         ...          ...        ...          ...        ...          ...
# XKX         NaN          NaN        NaN          NaN        NaN          NaN
# YEM         NaN          NaN        NaN          NaN        NaN          NaN
# ZAF       59.05        10.14      61.96         9.46      64.10          NaN
# ZMB         NaN          NaN        NaN          NaN        NaN          NaN
# ZWE         NaN          NaN        NaN          NaN        NaN          NaN
#
#       2019-Male  2020-Female  2020-Male
# iso3
# ABW         NaN          NaN        NaN
# AFG         NaN          NaN        NaN
# AGO         NaN          NaN        NaN
# ALB        3.55         0.64       3.55
# AND         NaN          NaN        NaN
# ...         ...          ...        ...
# XKX         NaN          NaN        NaN
# YEM         NaN          NaN        NaN
# ZAF         NaN          NaN        NaN
# ZMB         NaN          NaN        NaN
# ZWE         NaN          NaN        NaN
#
# [207 rows x 69 columns]

# %%
df.to_csv(r'processed_data/fin_df.csv')
