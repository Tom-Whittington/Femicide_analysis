# %% [markdown]
# # Dataset Creation

# %%
import pandas as pd
import numpy as np
import requests
import io
import wbgapi as wb
from bs4 import BeautifulSoup
import cache_magic #pip install ipython_cache
import country_converter as coco
# Out:
# %cache magic is now registered in ipython

# %% [markdown]
# # Femicide Data

# %% [markdown]
# ### Femicide data is downloaded from github and loaded as df_fem

# %%
url = 'https://raw.githubusercontent.com/Tom-Whittington/Femicide_analysis/main/processed_data/original_femicide_data.csv'

# %%
# %cache download = requests.get(url).content
# Out:
# loading cached value for variable 'download'. Time since pickling  148 days, 19:27:01.258751

# %%
df_fem = pd.read_csv(io.StringIO(download.decode('utf-8')),
                dtype={'iso3_code' : 'category',
                           'Region' : 'category',
                           'Subregion' : 'category',
                           'country' : 'category',
                           'Indicator' : 'category',
                           'Gender' : 'category',
                           'Source' : 'category',
                           'Unit' : 'category',
                          'Year' : 'string'})

# %%
df_fem
# Out:
#        Region           Subregion      country iso3_code  \
# 0        Asia       Southern Asia  Afghanistan       AFG
# 1        Asia       Southern Asia  Afghanistan       AFG
# 2        Asia       Southern Asia  Afghanistan       AFG
# 3        Asia       Southern Asia  Afghanistan       AFG
# 4        Asia       Southern Asia  Afghanistan       AFG
# ...       ...                 ...          ...       ...
# 24387  Africa  Sub-Saharan Africa     Zimbabwe       ZWE
# 24388  Africa  Sub-Saharan Africa     Zimbabwe       ZWE
# 24389  Africa  Sub-Saharan Africa     Zimbabwe       ZWE
# 24390  Africa  Sub-Saharan Africa     Zimbabwe       ZWE
# 24391  Africa  Sub-Saharan Africa     Zimbabwe       ZWE
#
#                     Indicator Disaggregation            Gender Source  \
# 0      Homicide: # of victims              -  Total (all ages)    NSO
# 1      Homicide: # of victims              -  Total (all ages)    NSO
# 2      Homicide: # of victims              -  Total (all ages)    NSO
# 3      Homicide: # of victims              -  Total (all ages)    NSO
# 4      Homicide: # of victims              -  Total (all ages)    NSO
# ...                       ...            ...               ...    ...
# 24387  Homicide: # of victims              -  Total (all ages)    WHO
# 24388  Homicide: # of victims              -  Total (all ages)    WHO
# 24389  Homicide: # of victims              -  Total (all ages)    WHO
# 24390  Homicide: # of victims              -  Total (all ages)    WHO
# 24391  Homicide: # of victims              -  Total (all ages)    WHO
#
#                                Unit  Year Value Footnote
# 0                             Count  2009  1115      NaN
# 1      Rate per  100,000 population  2009  3.93      NaN
# 2                             Count  2010   983      NaN
# 3      Rate per  100,000 population  2010  3.37      NaN
# 4                             Count  2011  1231      NaN
# ...                             ...   ...   ...      ...
# 24387  Rate per  100,000 population  2006  8.82      NaN
# 24388                         Count  2010   711      NaN
# 24389  Rate per  100,000 population  2010   5.6      NaN
# 24390                         Count  2012   981      NaN
# 24391  Rate per  100,000 population  2012  7.48      NaN
#
# [24392 rows x 12 columns]

# %%
df_fem.dtypes
# Out:
# Region            category
# Subregion         category
# country           category
# iso3_code         category
# Indicator         category
# Disaggregation      object
# Gender            category
# Source            category
# Unit              category
# Year                string
# Value               object
# Footnote            object
# dtype: object

# %% [markdown]
# ### Columns are renamed

# %%
df_fem.columns = [col.lower() for col in df_fem.columns]
df_fem = df_fem.rename(columns={'iso3_code' : 'iso3'})
df_fem['year'] = pd.to_datetime(df_fem['year'], format='%Y')

# %%
df_fem
# Out:
#        region           subregion      country iso3               indicator  \
# 0        Asia       Southern Asia  Afghanistan  AFG  Homicide: # of victims
# 1        Asia       Southern Asia  Afghanistan  AFG  Homicide: # of victims
# 2        Asia       Southern Asia  Afghanistan  AFG  Homicide: # of victims
# 3        Asia       Southern Asia  Afghanistan  AFG  Homicide: # of victims
# 4        Asia       Southern Asia  Afghanistan  AFG  Homicide: # of victims
# ...       ...                 ...          ...  ...                     ...
# 24387  Africa  Sub-Saharan Africa     Zimbabwe  ZWE  Homicide: # of victims
# 24388  Africa  Sub-Saharan Africa     Zimbabwe  ZWE  Homicide: # of victims
# 24389  Africa  Sub-Saharan Africa     Zimbabwe  ZWE  Homicide: # of victims
# 24390  Africa  Sub-Saharan Africa     Zimbabwe  ZWE  Homicide: # of victims
# 24391  Africa  Sub-Saharan Africa     Zimbabwe  ZWE  Homicide: # of victims
#
#       disaggregation            gender source                          unit  \
# 0                  -  Total (all ages)    NSO                         Count
# 1                  -  Total (all ages)    NSO  Rate per  100,000 population
# 2                  -  Total (all ages)    NSO                         Count
# 3                  -  Total (all ages)    NSO  Rate per  100,000 population
# 4                  -  Total (all ages)    NSO                         Count
# ...              ...               ...    ...                           ...
# 24387              -  Total (all ages)    WHO  Rate per  100,000 population
# 24388              -  Total (all ages)    WHO                         Count
# 24389              -  Total (all ages)    WHO  Rate per  100,000 population
# 24390              -  Total (all ages)    WHO                         Count
# 24391              -  Total (all ages)    WHO  Rate per  100,000 population
#
#             year value footnote
# 0     2009-01-01  1115      NaN
# 1     2009-01-01  3.93      NaN
# 2     2010-01-01   983      NaN
# 3     2010-01-01  3.37      NaN
# 4     2011-01-01  1231      NaN
# ...          ...   ...      ...
# 24387 2006-01-01  8.82      NaN
# 24388 2010-01-01   711      NaN
# 24389 2010-01-01   5.6      NaN
# 24390 2012-01-01   981      NaN
# 24391 2012-01-01  7.48      NaN
#
# [24392 rows x 12 columns]

# %% [markdown]
# ### Filters out totals and only keeps male and female data

# %%
df_fem = df_fem.loc[df_fem['gender'] == 'Female']
df_fem
# Out:
#          region                        subregion  \
# 8          Asia                    Southern Asia
# 9          Asia                    Southern Asia
# 14         Asia                    Southern Asia
# 15         Asia                    Southern Asia
# 20         Asia                    Southern Asia
# ...         ...                              ...
# 24285  Americas  Latin America and the Caribbean
# 24290  Americas  Latin America and the Caribbean
# 24291  Americas  Latin America and the Caribbean
# 24372    Africa               Sub-Saharan Africa
# 24373    Africa               Sub-Saharan Africa
#
#                                   country iso3               indicator  \
# 8                             Afghanistan  AFG  Homicide: # of victims
# 9                             Afghanistan  AFG  Homicide: # of victims
# 14                            Afghanistan  AFG  Homicide: # of victims
# 15                            Afghanistan  AFG  Homicide: # of victims
# 20                            Afghanistan  AFG  Homicide: # of victims
# ...                                   ...  ...                     ...
# 24285  Venezuela (Bolivarian Republic of)  VEN  Homicide: # of victims
# 24290  Venezuela (Bolivarian Republic of)  VEN  Homicide: # of victims
# 24291  Venezuela (Bolivarian Republic of)  VEN  Homicide: # of victims
# 24372                            Zimbabwe  ZWE  Homicide: # of victims
# 24373                            Zimbabwe  ZWE  Homicide: # of victims
#
#       disaggregation  gender source                          unit       year  \
# 8                  -  Female    NSO                         Count 2015-01-01
# 9                  -  Female    NSO  Rate per  100,000 population 2015-01-01
# 14                 -  Female    NSO                         Count 2016-01-01
# 15                 -  Female    NSO  Rate per  100,000 population 2016-01-01
# 20                 -  Female    NSO                         Count 2017-01-01
# ...              ...     ...    ...                           ...        ...
# 24285              -  Female    CTS  Rate per  100,000 population 2016-01-01
# 24290              -  Female    CTS                         Count 2017-01-01
# 24291              -  Female    CTS  Rate per  100,000 population 2017-01-01
# 24372              -  Female     MD                         Count 1990-01-01
# 24373              -  Female     MD  Rate per  100,000 population 1990-01-01
#
#       value footnote
# 8        93      NaN
# 9      0.56      NaN
# 14      101      NaN
# 15     0.59      NaN
# 20      133      NaN
# ...     ...      ...
# 24285  5.36      NaN
# 24290   788      NaN
# 24291  5.31      NaN
# 24372   183      NaN
# 24373  3.49      NaN
#
# [7136 rows x 12 columns]

# %% [markdown]
# ### Filters out counts and leaves only count, sorts values and converts value column to numeric

# %%
df_fem = df_fem[df_fem['unit'] != 'Rate per  100,000 population']
df_fem = df_fem.sort_values(['year', 'gender', 'iso3'])
df_fem['value'] = pd.to_numeric(df_fem['value'], errors='coerce')
df_fem['iso3'] = df_fem['iso3'].replace({'KOS' : 'XKX'})
df_fem
# Out:
#          region                        subregion                   country  \
# 1192   Americas  Latin America and the Caribbean                     Aruba
# 898        Asia                     Western Asia                   Armenia
# 674    Americas  Latin America and the Caribbean       Antigua and Barbuda
# 1294    Oceania        Australia and New Zealand                 Australia
# 1560     Europe                   Western Europe                   Austria
# ...         ...                              ...                       ...
# 22436      Asia                     Central Asia                Tajikistan
# 22846    Africa                  Northern Africa                   Tunisia
# 23730  Americas                 Northern America  United States of America
# 24138   Oceania                        Melanesia                   Vanuatu
# 24144   Oceania                        Melanesia                   Vanuatu
#
#       iso3                                  indicator  \
# 1192   ABW                     Homicide: # of victims
# 898    ARM                     Homicide: # of victims
# 674    ATG                     Homicide: # of victims
# 1294   AUS                     Homicide: # of victims
# 1560   AUT                     Homicide: # of victims
# ...    ...                                        ...
# 22436  TJK  Homicide: # of victims - perpetrator IPFM
# 22846  TUN                     Homicide: # of victims
# 23730  USA  Homicide: # of victims - perpetrator IPFM
# 24138  VUT                     Homicide: # of victims
# 24144  VUT  Homicide: # of victims - perpetrator IPFM
#
#                                           disaggregation  gender    source  \
# 1192                                                   -  Female        MD
# 898                                                    -  Female     UNECE
# 674                                                    -  Female        MD
# 1294                                                   -  Female        MD
# 1560                                                   -  Female        MD
# ...                                                  ...     ...       ...
# 22436  Killed by Intimate partner or family member (I...  Female       CTS
# 22846                                                  -  Female  External
# 23730  Killed by Intimate partner or family member (I...  Female       FBI
# 24138                                                  -  Female  External
# 24144  Killed by Intimate partner or family member (I...  Female  External
#
#         unit       year   value                                  footnote
# 1192   Count 1990-01-01     0.0                                       NaN
# 898    Count 1990-01-01    22.0                                       NaN
# 674    Count 1990-01-01     1.0                                       NaN
# 1294   Count 1990-01-01   138.0                                       NaN
# 1560   Count 1990-01-01    39.0                                       NaN
# ...      ...        ...     ...                                       ...
# 22436  Count 2020-01-01     4.0  IPFM - Intimate partner or family member
# 22846  Count 2020-01-01   115.0                                       NaN
# 23730  Count 2020-01-01  1420.0  IPFM - Intimate partner or family member
# 24138  Count 2020-01-01     1.0                                       NaN
# 24144  Count 2020-01-01     1.0  IPFM - Intimate partner or family member
#
# [3568 rows x 12 columns]

# %%
df_IPV = df_fem[df_fem['disaggregation'].str.contains('Killed')]
df_IPV
# Out:
#          region                        subregion                   country  \
# 120      Europe                  Southern Europe                   Albania
# 992        Asia                     Western Asia                   Armenia
# 1390    Oceania        Australia and New Zealand                 Australia
# 1654     Europe                   Western Europe                   Austria
# 2058   Americas  Latin America and the Caribbean                   Bahamas
# ...         ...                              ...                       ...
# 21990    Europe                  Northern Europe                    Sweden
# 21996    Europe                  Northern Europe                    Sweden
# 22436      Asia                     Central Asia                Tajikistan
# 23730  Americas                 Northern America  United States of America
# 24144   Oceania                        Melanesia                   Vanuatu
#
#       iso3                                  indicator  \
# 120    ALB  Homicide: # of victims - perpetrator IPFM
# 992    ARM  Homicide: # of victims - perpetrator IPFM
# 1390   AUS  Homicide: # of victims - perpetrator IPFM
# 1654   AUT  Homicide: # of victims - perpetrator IPFM
# 2058   BHS  Homicide: # of victims - perpetrator IPFM
# ...    ...                                        ...
# 21990  SWE    Homicide: # of victims - perpetrator IP
# 21996  SWE  Homicide: # of victims - perpetrator IPFM
# 22436  TJK  Homicide: # of victims - perpetrator IPFM
# 23730  USA  Homicide: # of victims - perpetrator IPFM
# 24144  VUT  Homicide: # of victims - perpetrator IPFM
#
#                                           disaggregation  gender    source  \
# 120    Killed by Intimate partner or family member (I...  Female       CTS
# 992    Killed by Intimate partner or family member (I...  Female       CTS
# 1390   Killed by Intimate partner or family member (I...  Female       CTS
# 1654   Killed by Intimate partner or family member (I...  Female       CTS
# 2058   Killed by Intimate partner or family member (I...  Female       CTS
# ...                                                  ...     ...       ...
# 21990                         Killed by Intimate partner  Female       CTS
# 21996  Killed by Intimate partner or family member (I...  Female  External
# 22436  Killed by Intimate partner or family member (I...  Female       CTS
# 23730  Killed by Intimate partner or family member (I...  Female       FBI
# 24144  Killed by Intimate partner or family member (I...  Female  External
#
#         unit       year   value                                  footnote
# 120    Count 2005-01-01     7.0  IPFM - Intimate partner or family member
# 992    Count 2005-01-01     2.0  IPFM - Intimate partner or family member
# 1390   Count 2005-01-01    70.0  IPFM - Intimate partner or family member
# 1654   Count 2005-01-01    39.0  IPFM - Intimate partner or family member
# 2058   Count 2005-01-01     4.0  IPFM - Intimate partner or family member
# ...      ...        ...     ...                                       ...
# 21990  Count 2020-01-01    13.0                     IP - Intimate partner
# 21996  Count 2020-01-01    13.0  IPFM - Intimate partner or family member
# 22436  Count 2020-01-01     4.0  IPFM - Intimate partner or family member
# 23730  Count 2020-01-01  1420.0  IPFM - Intimate partner or family member
# 24144  Count 2020-01-01     1.0  IPFM - Intimate partner or family member
#
# [1211 rows x 12 columns]

# %%
df_fem = df_fem[df_fem['disaggregation'] == '-']
df_fem = df_fem.set_index(['iso3','year'])

# %%
df_fem
# Out:
#                    region                        subregion  \
# iso3 year
# ABW  1990-01-01  Americas  Latin America and the Caribbean
# ARM  1990-01-01      Asia                     Western Asia
# ATG  1990-01-01  Americas  Latin America and the Caribbean
# AUS  1990-01-01   Oceania        Australia and New Zealand
# AUT  1990-01-01    Europe                   Western Europe
# ...                   ...                              ...
# SVN  2020-01-01    Europe                  Southern Europe
# SWE  2020-01-01    Europe                  Northern Europe
# TJK  2020-01-01      Asia                     Central Asia
# TUN  2020-01-01    Africa                  Northern Africa
# VUT  2020-01-01   Oceania                        Melanesia
#
#                              country               indicator disaggregation  \
# iso3 year
# ABW  1990-01-01                Aruba  Homicide: # of victims              -
# ARM  1990-01-01              Armenia  Homicide: # of victims              -
# ATG  1990-01-01  Antigua and Barbuda  Homicide: # of victims              -
# AUS  1990-01-01            Australia  Homicide: # of victims              -
# AUT  1990-01-01              Austria  Homicide: # of victims              -
# ...                              ...                     ...            ...
# SVN  2020-01-01             Slovenia  Homicide: # of victims              -
# SWE  2020-01-01               Sweden  Homicide: # of victims              -
# TJK  2020-01-01           Tajikistan  Homicide: # of victims              -
# TUN  2020-01-01              Tunisia  Homicide: # of victims              -
# VUT  2020-01-01              Vanuatu  Homicide: # of victims              -
#
#                  gender    source   unit  value footnote
# iso3 year
# ABW  1990-01-01  Female        MD  Count    0.0      NaN
# ARM  1990-01-01  Female     UNECE  Count   22.0      NaN
# ATG  1990-01-01  Female        MD  Count    1.0      NaN
# AUS  1990-01-01  Female        MD  Count  138.0      NaN
# AUT  1990-01-01  Female        MD  Count   39.0      NaN
# ...                 ...       ...    ...    ...      ...
# SVN  2020-01-01  Female  Covid-19  Count    6.0      NaN
# SWE  2020-01-01  Female  External  Count   25.0      NaN
# TJK  2020-01-01  Female       CTS  Count   10.0      NaN
# TUN  2020-01-01  Female  External  Count  115.0      NaN
# VUT  2020-01-01  Female  External  Count    1.0      NaN
#
# [2357 rows x 10 columns]

# %% [markdown]
# # Economic data

# %% [markdown]
# ## Worldbank data import

# %% [markdown]
# ### Economic data is imported from worldbank API
# 1. NY.GNP.PCAP.CD represents gross national income per capita
#
# 2. SI.POV.GINI represents the gini coefficient of each country
#
# 3. Years 2000-2023 are selected
#
# 4. Labels also returns country code
#
# 5. skipBlanks is turned off so we have a row for each year (easier merging)
#
# 6. each series is added to column
#
# 7. skipAggs returns only countries and not regions/aggregations
#
# 8. Result is cached as can be slow to return

# %%
# %cache df_wb = wb.data.DataFrame(['NY.GNP.PCAP.CD','SI.POV.GINI', 'SP.POP.TOTL.FE.IN', 'SH.STA.SUIC.FE.P5', 'SH.MMR.DTHS', 'VC.IHR.PSRC.FE.P5'], time=range(1990,2022), labels=True, skipBlanks =False, columns='series', skipAggs=True)
# Out:
# loading cached value for variable 'df_wb'. Time since pickling  2:07:37.173331

# %% [markdown]
# ### Index is reset, columns renamed and converted to datetime format. Extra time column is dropped and index is set to country code and year

# %%
df_wb = df_wb.reset_index()

df_wb = df_wb.rename(columns={'economy':'iso3',
                        'Time':'year',
                        'NY.GNP.PCAP.CD':'gnipc',
                        'SI.POV.GINI':'gini',
                        'Country':'country',
                        'SP.POP.TOTL.FE.IN' : 'fem_pop',
                        'SH.STA.SUIC.FE.P5' : 'suicide_rate',
                        'SH.MMR.DTHS' : 'mat_deaths',
                        'VC.IHR.PSRC.FE.P5' : 'femicide_rate'})

df_wb['year'] = pd.to_datetime(df_wb['year'], format='%Y')

df_wb['gnipc'] = pd.to_numeric(df_wb['gnipc'], errors='coerce')
df_wb['gini'] = pd.to_numeric(df_wb['gini'], errors='coerce')

df_wb = df_wb.drop(columns='time')

df_wb = df_wb.set_index(['iso3', 'year'])
df_wb
# Out:
#                      country   gnipc  mat_deaths  suicide_rate  gini  \
# iso3 year
# ZWE  2021-01-01     Zimbabwe  1530.0         NaN           NaN   NaN
#      2020-01-01     Zimbabwe  1460.0      1700.0           NaN   NaN
#      2019-01-01     Zimbabwe  1450.0      1900.0           8.8  50.3
#      2018-01-01     Zimbabwe  1550.0      1700.0           8.7   NaN
#      2017-01-01     Zimbabwe  1170.0      1800.0           9.6  44.3
# ...                      ...     ...         ...           ...   ...
# AFG  1994-01-01  Afghanistan     NaN         NaN           NaN   NaN
#      1993-01-01  Afghanistan     NaN         NaN           NaN   NaN
#      1992-01-01  Afghanistan     NaN         NaN           NaN   NaN
#      1991-01-01  Afghanistan     NaN         NaN           NaN   NaN
#      1990-01-01  Afghanistan     NaN         NaN           NaN   NaN
#
#                    fem_pop  femicide_rate
# iso3 year
# ZWE  2021-01-01  8449834.0       1.869859
#      2020-01-01  8284447.0       1.762339
#      2019-01-01  8122618.0       2.055987
#      2018-01-01  7966181.0       2.046150
#      2017-01-01  7810471.0            NaN
# ...                    ...            ...
# AFG  1994-01-01  7722096.0            NaN
#      1993-01-01  7000119.0            NaN
#      1992-01-01  6028939.0            NaN
#      1991-01-01  5372208.0            NaN
#      1990-01-01  5346409.0            NaN
#
# [6944 rows x 7 columns]

# %%
df_wb['fem_pop'] = df_wb['fem_pop'].astype('int64')

# %%
df_wb.isna().sum()
# Out:
# country             0
# gnipc            1073
# mat_deaths       3059
# suicide_rate     3284
# gini             5137
# fem_pop             0
# femicide_rate    4405
# dtype: int64

# %%
df_wb
# Out:
#                      country   gnipc  mat_deaths  suicide_rate  gini  fem_pop  \
# iso3 year
# ZWE  2021-01-01     Zimbabwe  1530.0         NaN           NaN   NaN  8449834
#      2020-01-01     Zimbabwe  1460.0      1700.0           NaN   NaN  8284447
#      2019-01-01     Zimbabwe  1450.0      1900.0           8.8  50.3  8122618
#      2018-01-01     Zimbabwe  1550.0      1700.0           8.7   NaN  7966181
#      2017-01-01     Zimbabwe  1170.0      1800.0           9.6  44.3  7810471
# ...                      ...     ...         ...           ...   ...      ...
# AFG  1994-01-01  Afghanistan     NaN         NaN           NaN   NaN  7722096
#      1993-01-01  Afghanistan     NaN         NaN           NaN   NaN  7000119
#      1992-01-01  Afghanistan     NaN         NaN           NaN   NaN  6028939
#      1991-01-01  Afghanistan     NaN         NaN           NaN   NaN  5372208
#      1990-01-01  Afghanistan     NaN         NaN           NaN   NaN  5346409
#
#                  femicide_rate
# iso3 year
# ZWE  2021-01-01       1.869859
#      2020-01-01       1.762339
#      2019-01-01       2.055987
#      2018-01-01       2.046150
#      2017-01-01            NaN
# ...                        ...
# AFG  1994-01-01            NaN
#      1993-01-01            NaN
#      1992-01-01            NaN
#      1991-01-01            NaN
#      1990-01-01            NaN
#
# [6944 rows x 7 columns]

# %%
df_wb['suicide_count'] =round((df_wb['suicide_rate'] / 100000) * df_wb['fem_pop'], 0)
df_wb['femicide_count'] = round((df_wb['femicide_rate'] / 100000) * df_wb['fem_pop'], 0)

# %%
df_wb
# Out:
#                      country   gnipc  mat_deaths  suicide_rate  gini  fem_pop  \
# iso3 year
# ZWE  2021-01-01     Zimbabwe  1530.0         NaN           NaN   NaN  8449834
#      2020-01-01     Zimbabwe  1460.0      1700.0           NaN   NaN  8284447
#      2019-01-01     Zimbabwe  1450.0      1900.0           8.8  50.3  8122618
#      2018-01-01     Zimbabwe  1550.0      1700.0           8.7   NaN  7966181
#      2017-01-01     Zimbabwe  1170.0      1800.0           9.6  44.3  7810471
# ...                      ...     ...         ...           ...   ...      ...
# AFG  1994-01-01  Afghanistan     NaN         NaN           NaN   NaN  7722096
#      1993-01-01  Afghanistan     NaN         NaN           NaN   NaN  7000119
#      1992-01-01  Afghanistan     NaN         NaN           NaN   NaN  6028939
#      1991-01-01  Afghanistan     NaN         NaN           NaN   NaN  5372208
#      1990-01-01  Afghanistan     NaN         NaN           NaN   NaN  5346409
#
#                  femicide_rate  suicide_count  femicide_count
# iso3 year
# ZWE  2021-01-01       1.869859            NaN           158.0
#      2020-01-01       1.762339            NaN           146.0
#      2019-01-01       2.055987          715.0           167.0
#      2018-01-01       2.046150          693.0           163.0
#      2017-01-01            NaN          750.0             NaN
# ...                        ...            ...             ...
# AFG  1994-01-01            NaN            NaN             NaN
#      1993-01-01            NaN            NaN             NaN
#      1992-01-01            NaN            NaN             NaN
#      1991-01-01            NaN            NaN             NaN
#      1990-01-01            NaN            NaN             NaN
#
# [6944 rows x 9 columns]

# %%
df_wb
# Out:
#                      country   gnipc  mat_deaths  suicide_rate  gini  fem_pop  \
# iso3 year
# ZWE  2021-01-01     Zimbabwe  1530.0         NaN           NaN   NaN  8449834
#      2020-01-01     Zimbabwe  1460.0      1700.0           NaN   NaN  8284447
#      2019-01-01     Zimbabwe  1450.0      1900.0           8.8  50.3  8122618
#      2018-01-01     Zimbabwe  1550.0      1700.0           8.7   NaN  7966181
#      2017-01-01     Zimbabwe  1170.0      1800.0           9.6  44.3  7810471
# ...                      ...     ...         ...           ...   ...      ...
# AFG  1994-01-01  Afghanistan     NaN         NaN           NaN   NaN  7722096
#      1993-01-01  Afghanistan     NaN         NaN           NaN   NaN  7000119
#      1992-01-01  Afghanistan     NaN         NaN           NaN   NaN  6028939
#      1991-01-01  Afghanistan     NaN         NaN           NaN   NaN  5372208
#      1990-01-01  Afghanistan     NaN         NaN           NaN   NaN  5346409
#
#                  femicide_rate  suicide_count  femicide_count
# iso3 year
# ZWE  2021-01-01       1.869859            NaN           158.0
#      2020-01-01       1.762339            NaN           146.0
#      2019-01-01       2.055987          715.0           167.0
#      2018-01-01       2.046150          693.0           163.0
#      2017-01-01            NaN          750.0             NaN
# ...                        ...            ...             ...
# AFG  1994-01-01            NaN            NaN             NaN
#      1993-01-01            NaN            NaN             NaN
#      1992-01-01            NaN            NaN             NaN
#      1991-01-01            NaN            NaN             NaN
#      1990-01-01            NaN            NaN             NaN
#
# [6944 rows x 9 columns]

# %%
df_wb_femicide =df_wb.reset_index()
df_wb = df_wb.drop(columns='femicide_count')
df_wb_femicide = df_wb_femicide[['iso3', 'year', 'femicide_count']]
df_wb_femicide['source'] = 'WB'
df_wb_femicide = df_wb_femicide.set_index(['iso3', 'year'])
df_wb_femicide
# Out:
#                  femicide_count source
# iso3 year
# ZWE  2021-01-01           158.0     WB
#      2020-01-01           146.0     WB
#      2019-01-01           167.0     WB
#      2018-01-01           163.0     WB
#      2017-01-01             NaN     WB
# ...                         ...    ...
# AFG  1994-01-01             NaN     WB
#      1993-01-01             NaN     WB
#      1992-01-01             NaN     WB
#      1991-01-01             NaN     WB
#      1990-01-01             NaN     WB
#
# [6944 rows x 2 columns]

# %%
df_wb_femicide = df_wb_femicide.dropna()
df_wb_femicide
# Out:
#                  femicide_count source
# iso3 year
# ZWE  2021-01-01           158.0     WB
#      2020-01-01           146.0     WB
#      2019-01-01           167.0     WB
#      2018-01-01           163.0     WB
#      1990-01-01           183.0     WB
# ...                         ...    ...
# ALB  1994-01-01            12.0     WB
#      1993-01-01            16.0     WB
#      1992-01-01            14.0     WB
# AFG  2019-01-01           238.0     WB
#      2018-01-01           261.0     WB
#
# [2539 rows x 2 columns]

# %% [markdown]
# Filter out all rows that are already in the previous dataset. Important to note that some years have differences in the values and frequently 2021 is significantly different (maybe due to reporting being done mid year?)

# %%
df_fem = df_fem[~df_fem.index.isin(df_wb_femicide.index)]
df_fem = df_fem.rename(columns={'value' : 'femicide_count'})
df_fem
# Out:
#                    region                        subregion  \
# iso3 year
# MSR  1990-01-01  Americas  Latin America and the Caribbean
# AIA  1991-01-01  Americas  Latin America and the Caribbean
# MSR  1991-01-01  Americas  Latin America and the Caribbean
#      1992-01-01  Americas  Latin America and the Caribbean
# AIA  1993-01-01  Americas  Latin America and the Caribbean
# MSR  1993-01-01  Americas  Latin America and the Caribbean
#      1994-01-01  Americas  Latin America and the Caribbean
#      1995-01-01  Americas  Latin America and the Caribbean
#      1996-01-01  Americas  Latin America and the Caribbean
#      1997-01-01  Americas  Latin America and the Caribbean
#      1998-01-01  Americas  Latin America and the Caribbean
#      1999-01-01  Americas  Latin America and the Caribbean
# AIA  2000-01-01  Americas  Latin America and the Caribbean
# MSR  2000-01-01  Americas  Latin America and the Caribbean
#      2001-01-01  Americas  Latin America and the Caribbean
#      2002-01-01  Americas  Latin America and the Caribbean
#      2003-01-01  Americas  Latin America and the Caribbean
# GLP  2004-01-01  Americas  Latin America and the Caribbean
# MSR  2004-01-01  Americas  Latin America and the Caribbean
# REU  2004-01-01    Africa               Sub-Saharan Africa
# GLP  2005-01-01  Americas  Latin America and the Caribbean
# MSR  2005-01-01  Americas  Latin America and the Caribbean
# REU  2005-01-01    Africa               Sub-Saharan Africa
# GLP  2006-01-01  Americas  Latin America and the Caribbean
# GUF  2006-01-01  Americas  Latin America and the Caribbean
# MSR  2006-01-01  Americas  Latin America and the Caribbean
# MTQ  2006-01-01  Americas  Latin America and the Caribbean
# REU  2006-01-01    Africa               Sub-Saharan Africa
# SPM  2006-01-01  Americas                 Northern America
# GUF  2007-01-01  Americas  Latin America and the Caribbean
# MTQ  2007-01-01  Americas  Latin America and the Caribbean
# REU  2007-01-01    Africa               Sub-Saharan Africa
# AIA  2008-01-01  Americas  Latin America and the Caribbean
# GLP  2008-01-01  Americas  Latin America and the Caribbean
# GUF  2008-01-01  Americas  Latin America and the Caribbean
# MSR  2008-01-01  Americas  Latin America and the Caribbean
# MTQ  2008-01-01  Americas  Latin America and the Caribbean
# REU  2008-01-01    Africa               Sub-Saharan Africa
# AIA  2009-01-01  Americas  Latin America and the Caribbean
# GLP  2009-01-01  Americas  Latin America and the Caribbean
# GUF  2009-01-01  Americas  Latin America and the Caribbean
# MTQ  2009-01-01  Americas  Latin America and the Caribbean
# REU  2009-01-01    Africa               Sub-Saharan Africa
# VAT  2009-01-01    Europe                  Southern Europe
#      2010-01-01    Europe                  Southern Europe
#      2011-01-01    Europe                  Southern Europe
# MSR  2012-01-01  Americas  Latin America and the Caribbean
# VAT  2012-01-01    Europe                  Southern Europe
# AIA  2013-01-01  Americas  Latin America and the Caribbean
# VAT  2013-01-01    Europe                  Southern Europe
# CMR  2014-01-01    Africa               Sub-Saharan Africa
# VAT  2014-01-01    Europe                  Southern Europe
# AFG  2015-01-01      Asia                    Southern Asia
# GTM  2015-01-01  Americas  Latin America and the Caribbean
# VAT  2015-01-01    Europe                  Southern Europe
# AFG  2016-01-01      Asia                    Southern Asia
#      2017-01-01      Asia                    Southern Asia
# LIE  2019-01-01    Europe                   Western Europe
# SYR  2019-01-01      Asia                     Western Asia
#
#                                    country               indicator  \
# iso3 year
# MSR  1990-01-01                 Montserrat  Homicide: # of victims
# AIA  1991-01-01                   Anguilla  Homicide: # of victims
# MSR  1991-01-01                 Montserrat  Homicide: # of victims
#      1992-01-01                 Montserrat  Homicide: # of victims
# AIA  1993-01-01                   Anguilla  Homicide: # of victims
# MSR  1993-01-01                 Montserrat  Homicide: # of victims
#      1994-01-01                 Montserrat  Homicide: # of victims
#      1995-01-01                 Montserrat  Homicide: # of victims
#      1996-01-01                 Montserrat  Homicide: # of victims
#      1997-01-01                 Montserrat  Homicide: # of victims
#      1998-01-01                 Montserrat  Homicide: # of victims
#      1999-01-01                 Montserrat  Homicide: # of victims
# AIA  2000-01-01                   Anguilla  Homicide: # of victims
# MSR  2000-01-01                 Montserrat  Homicide: # of victims
#      2001-01-01                 Montserrat  Homicide: # of victims
#      2002-01-01                 Montserrat  Homicide: # of victims
#      2003-01-01                 Montserrat  Homicide: # of victims
# GLP  2004-01-01                 Guadeloupe  Homicide: # of victims
# MSR  2004-01-01                 Montserrat  Homicide: # of victims
# REU  2004-01-01                    Réunion  Homicide: # of victims
# GLP  2005-01-01                 Guadeloupe  Homicide: # of victims
# MSR  2005-01-01                 Montserrat  Homicide: # of victims
# REU  2005-01-01                    Réunion  Homicide: # of victims
# GLP  2006-01-01                 Guadeloupe  Homicide: # of victims
# GUF  2006-01-01              French Guiana  Homicide: # of victims
# MSR  2006-01-01                 Montserrat  Homicide: # of victims
# MTQ  2006-01-01                 Martinique  Homicide: # of victims
# REU  2006-01-01                    Réunion  Homicide: # of victims
# SPM  2006-01-01  Saint Pierre and Miquelon  Homicide: # of victims
# GUF  2007-01-01              French Guiana  Homicide: # of victims
# MTQ  2007-01-01                 Martinique  Homicide: # of victims
# REU  2007-01-01                    Réunion  Homicide: # of victims
# AIA  2008-01-01                   Anguilla  Homicide: # of victims
# GLP  2008-01-01                 Guadeloupe  Homicide: # of victims
# GUF  2008-01-01              French Guiana  Homicide: # of victims
# MSR  2008-01-01                 Montserrat  Homicide: # of victims
# MTQ  2008-01-01                 Martinique  Homicide: # of victims
# REU  2008-01-01                    Réunion  Homicide: # of victims
# AIA  2009-01-01                   Anguilla  Homicide: # of victims
# GLP  2009-01-01                 Guadeloupe  Homicide: # of victims
# GUF  2009-01-01              French Guiana  Homicide: # of victims
# MTQ  2009-01-01                 Martinique  Homicide: # of victims
# REU  2009-01-01                    Réunion  Homicide: # of victims
# VAT  2009-01-01                   Holy See  Homicide: # of victims
#      2010-01-01                   Holy See  Homicide: # of victims
#      2011-01-01                   Holy See  Homicide: # of victims
# MSR  2012-01-01                 Montserrat  Homicide: # of victims
# VAT  2012-01-01                   Holy See  Homicide: # of victims
# AIA  2013-01-01                   Anguilla  Homicide: # of victims
# VAT  2013-01-01                   Holy See  Homicide: # of victims
# CMR  2014-01-01                   Cameroon  Homicide: # of victims
# VAT  2014-01-01                   Holy See  Homicide: # of victims
# AFG  2015-01-01                Afghanistan  Homicide: # of victims
# GTM  2015-01-01                  Guatemala  Homicide: # of victims
# VAT  2015-01-01                   Holy See  Homicide: # of victims
# AFG  2016-01-01                Afghanistan  Homicide: # of victims
#      2017-01-01                Afghanistan  Homicide: # of victims
# LIE  2019-01-01              Liechtenstein  Homicide: # of victims
# SYR  2019-01-01       Syrian Arab Republic  Homicide: # of victims
#
#                 disaggregation  gender    source   unit  femicide_count  \
# iso3 year
# MSR  1990-01-01              -  Female        MD  Count             0.0
# AIA  1991-01-01              -  Female        MD  Count             0.0
# MSR  1991-01-01              -  Female        MD  Count             0.0
#      1992-01-01              -  Female        MD  Count             0.0
# AIA  1993-01-01              -  Female        MD  Count             1.0
# MSR  1993-01-01              -  Female        MD  Count             0.0
#      1994-01-01              -  Female        MD  Count             1.0
#      1995-01-01              -  Female        MD  Count             0.0
#      1996-01-01              -  Female        MD  Count             0.0
#      1997-01-01              -  Female        MD  Count             0.0
#      1998-01-01              -  Female        MD  Count             0.0
#      1999-01-01              -  Female        MD  Count             0.0
# AIA  2000-01-01              -  Female        MD  Count             0.0
# MSR  2000-01-01              -  Female        MD  Count             0.0
#      2001-01-01              -  Female        MD  Count             0.0
#      2002-01-01              -  Female        MD  Count             0.0
#      2003-01-01              -  Female        MD  Count             0.0
# GLP  2004-01-01              -  Female        MD  Count             9.0
# MSR  2004-01-01              -  Female        MD  Count             0.0
# REU  2004-01-01              -  Female        MD  Count            10.0
# GLP  2005-01-01              -  Female        MD  Count             1.0
# MSR  2005-01-01              -  Female        MD  Count             0.0
# REU  2005-01-01              -  Female        MD  Count             7.0
# GLP  2006-01-01              -  Female        MD  Count             6.0
# GUF  2006-01-01              -  Female        MD  Count             3.0
# MSR  2006-01-01              -  Female        MD  Count             0.0
# MTQ  2006-01-01              -  Female        MD  Count             5.0
# REU  2006-01-01              -  Female        MD  Count             8.0
# SPM  2006-01-01              -  Female       WHO  Count             0.0
# GUF  2007-01-01              -  Female        MD  Count             1.0
# MTQ  2007-01-01              -  Female        MD  Count             5.0
# REU  2007-01-01              -  Female        MD  Count             8.0
# AIA  2008-01-01              -  Female        MD  Count             0.0
# GLP  2008-01-01              -  Female        MD  Count             8.0
# GUF  2008-01-01              -  Female        MD  Count             1.0
# MSR  2008-01-01              -  Female        MD  Count             0.0
# MTQ  2008-01-01              -  Female        MD  Count             4.0
# REU  2008-01-01              -  Female        MD  Count             4.0
# AIA  2009-01-01              -  Female        MD  Count             0.0
# GLP  2009-01-01              -  Female        MD  Count             5.0
# GUF  2009-01-01              -  Female        MD  Count             5.0
# MTQ  2009-01-01              -  Female        MD  Count             3.0
# REU  2009-01-01              -  Female        MD  Count             5.0
# VAT  2009-01-01              -  Female       CTS  Count             0.0
#      2010-01-01              -  Female       CTS  Count             0.0
#      2011-01-01              -  Female       CTS  Count             0.0
# MSR  2012-01-01              -  Female        MD  Count             1.0
# VAT  2012-01-01              -  Female       CTS  Count             0.0
# AIA  2013-01-01              -  Female        MD  Count             0.0
# VAT  2013-01-01              -  Female       CTS  Count             0.0
# CMR  2014-01-01              -  Female       CTS  Count            91.0
# VAT  2014-01-01              -  Female       CTS  Count             0.0
# AFG  2015-01-01              -  Female       NSO  Count            93.0
# GTM  2015-01-01              -  Female       CTS  Count           630.0
# VAT  2015-01-01              -  Female       CTS  Count             0.0
# AFG  2016-01-01              -  Female       NSO  Count           101.0
#      2017-01-01              -  Female       NSO  Count           133.0
# LIE  2019-01-01              -  Female       CTS  Count             0.0
# SYR  2019-01-01              -  Female  External  Count           747.0
#
#                 footnote
# iso3 year
# MSR  1990-01-01      NaN
# AIA  1991-01-01      NaN
# MSR  1991-01-01      NaN
#      1992-01-01      NaN
# AIA  1993-01-01      NaN
# MSR  1993-01-01      NaN
#      1994-01-01      NaN
#      1995-01-01      NaN
#      1996-01-01      NaN
#      1997-01-01      NaN
#      1998-01-01      NaN
#      1999-01-01      NaN
# AIA  2000-01-01      NaN
# MSR  2000-01-01      NaN
#      2001-01-01      NaN
#      2002-01-01      NaN
#      2003-01-01      NaN
# GLP  2004-01-01      NaN
# MSR  2004-01-01      NaN
# REU  2004-01-01      NaN
# GLP  2005-01-01      NaN
# MSR  2005-01-01      NaN
# REU  2005-01-01      NaN
# GLP  2006-01-01      NaN
# GUF  2006-01-01      NaN
# MSR  2006-01-01      NaN
# MTQ  2006-01-01      NaN
# REU  2006-01-01      NaN
# SPM  2006-01-01      NaN
# GUF  2007-01-01      NaN
# MTQ  2007-01-01      NaN
# REU  2007-01-01      NaN
# AIA  2008-01-01      NaN
# GLP  2008-01-01      NaN
# GUF  2008-01-01      NaN
# MSR  2008-01-01      NaN
# MTQ  2008-01-01      NaN
# REU  2008-01-01      NaN
# AIA  2009-01-01      NaN
# GLP  2009-01-01      NaN
# GUF  2009-01-01      NaN
# MTQ  2009-01-01      NaN
# REU  2009-01-01      NaN
# VAT  2009-01-01      NaN
#      2010-01-01      NaN
#      2011-01-01      NaN
# MSR  2012-01-01      NaN
# VAT  2012-01-01      NaN
# AIA  2013-01-01      NaN
# VAT  2013-01-01      NaN
# CMR  2014-01-01      NaN
# VAT  2014-01-01      NaN
# AFG  2015-01-01      NaN
# GTM  2015-01-01      NaN
# VAT  2015-01-01      NaN
# AFG  2016-01-01      NaN
#      2017-01-01      NaN
# LIE  2019-01-01      NaN
# SYR  2019-01-01      NaN

# %%
df_fem = pd.concat([df_fem, df_wb_femicide])
df_fem = df_fem.reset_index()
df_fem[['gender', 'disaggregation', 'indicator', 'unit']] = ['Female', '-', 'Homicide: # of victims', 'Count']
df_fem
# Out:
#      iso3       year    region                        subregion     country  \
# 0     MSR 1990-01-01  Americas  Latin America and the Caribbean  Montserrat
# 1     AIA 1991-01-01  Americas  Latin America and the Caribbean    Anguilla
# 2     MSR 1991-01-01  Americas  Latin America and the Caribbean  Montserrat
# 3     MSR 1992-01-01  Americas  Latin America and the Caribbean  Montserrat
# 4     AIA 1993-01-01  Americas  Latin America and the Caribbean    Anguilla
# ...   ...        ...       ...                              ...         ...
# 2593  ALB 1994-01-01       NaN                              NaN         NaN
# 2594  ALB 1993-01-01       NaN                              NaN         NaN
# 2595  ALB 1992-01-01       NaN                              NaN         NaN
# 2596  AFG 2019-01-01       NaN                              NaN         NaN
# 2597  AFG 2018-01-01       NaN                              NaN         NaN
#
#                    indicator disaggregation  gender source   unit  \
# 0     Homicide: # of victims              -  Female     MD  Count
# 1     Homicide: # of victims              -  Female     MD  Count
# 2     Homicide: # of victims              -  Female     MD  Count
# 3     Homicide: # of victims              -  Female     MD  Count
# 4     Homicide: # of victims              -  Female     MD  Count
# ...                      ...            ...     ...    ...    ...
# 2593  Homicide: # of victims              -  Female     WB  Count
# 2594  Homicide: # of victims              -  Female     WB  Count
# 2595  Homicide: # of victims              -  Female     WB  Count
# 2596  Homicide: # of victims              -  Female     WB  Count
# 2597  Homicide: # of victims              -  Female     WB  Count
#
#       femicide_count footnote
# 0                0.0      NaN
# 1                0.0      NaN
# 2                0.0      NaN
# 3                0.0      NaN
# 4                1.0      NaN
# ...              ...      ...
# 2593            12.0      NaN
# 2594            16.0      NaN
# 2595            14.0      NaN
# 2596           238.0      NaN
# 2597           261.0      NaN
#
# [2598 rows x 12 columns]

# %%
converter = coco.CountryConverter()
df_fem['region'] = converter.convert(names=df_fem['iso3'], src="ISO3", to="continent")
df_fem['subregion'] = converter.convert(names=df_fem['iso3'], src="ISO3", to="UNregion")
df_fem['country'] = converter.convert(names=df_fem['iso3'], src="ISO3", to="name_short")

# %%
df_fem = df_fem.dropna(subset='femicide_count')
df_fem
# Out:
#      iso3       year   region        subregion      country  \
# 0     MSR 1990-01-01  America        Caribbean   Montserrat
# 1     AIA 1991-01-01  America        Caribbean     Anguilla
# 2     MSR 1991-01-01  America        Caribbean   Montserrat
# 3     MSR 1992-01-01  America        Caribbean   Montserrat
# 4     AIA 1993-01-01  America        Caribbean     Anguilla
# ...   ...        ...      ...              ...          ...
# 2593  ALB 1994-01-01   Europe  Southern Europe      Albania
# 2594  ALB 1993-01-01   Europe  Southern Europe      Albania
# 2595  ALB 1992-01-01   Europe  Southern Europe      Albania
# 2596  AFG 2019-01-01     Asia    Southern Asia  Afghanistan
# 2597  AFG 2018-01-01     Asia    Southern Asia  Afghanistan
#
#                    indicator disaggregation  gender source   unit  \
# 0     Homicide: # of victims              -  Female     MD  Count
# 1     Homicide: # of victims              -  Female     MD  Count
# 2     Homicide: # of victims              -  Female     MD  Count
# 3     Homicide: # of victims              -  Female     MD  Count
# 4     Homicide: # of victims              -  Female     MD  Count
# ...                      ...            ...     ...    ...    ...
# 2593  Homicide: # of victims              -  Female     WB  Count
# 2594  Homicide: # of victims              -  Female     WB  Count
# 2595  Homicide: # of victims              -  Female     WB  Count
# 2596  Homicide: # of victims              -  Female     WB  Count
# 2597  Homicide: # of victims              -  Female     WB  Count
#
#       femicide_count footnote
# 0                0.0      NaN
# 1                0.0      NaN
# 2                0.0      NaN
# 3                0.0      NaN
# 4                1.0      NaN
# ...              ...      ...
# 2593            12.0      NaN
# 2594            16.0      NaN
# 2595            14.0      NaN
# 2596           238.0      NaN
# 2597           261.0      NaN
#
# [2598 rows x 12 columns]

# %% [markdown]
# ## CIA data

# %% [markdown]
# ### Gets webpage from url

# %%
url = 'https://www.cia.gov/the-world-factbook/field/gini-index-coefficient-distribution-of-family-income/country-comparison'

# %cache r = requests.get(url)

soup = BeautifulSoup(r.text, 'lxml')
# Out:
# loading cached value for variable 'r'. Time since pickling  148 days, 19:28:00.591099

# %% [markdown]
# ### Finds first table on page, extracts headers from first row and then loops over table and creates dataframe from values

# %%
table = soup.findAll('table')[0]

headers = [x.text for x in table.findChildren('th')[1:]]

row_list = headers
table_list = []
for row in table.findChildren('tr'):

    for cell in row.findChildren('td')[1:]:
        row_list.append(cell.text)
    table_list.append(row_list)
    row_list = []

df_cia = pd.DataFrame(table_list)

# %% [markdown]
# ### Adds gini label to first row and then promotes first row to headers

# %%
df_cia.iloc[0,1]='gini'

df_cia.columns= df_cia.iloc[0,:]

df_cia = df_cia[1:]

df_cia
# Out:
# 0                     Country  gini Date of Information
# 1                South Africa  63.0           2014 est.
# 2                     Namibia  59.1           2015 est.
# 3                      Zambia  57.1           2015 est.
# 4    Central African Republic  56.2           2008 est.
# 5                    Eswatini  54.6           2016 est.
# ..                        ...   ...                 ...
# 173                  Slovakia  25.2           2016 est.
# 174                   Belarus  24.4           2020 est.
# 175                  Slovenia  24.2           2017 est.
# 176             Faroe Islands  22.7           2013 est.
# 177                    Jersey   0.3           2014 est.
#
# [177 rows x 3 columns]

# %% [markdown]
# ### iso3 codes are generated for CIA data set by the worldbank api, Nas are dropped, year and iso3 set as index ready for filling in blanks

# %%
df_cia['iso3'] = wb.economy.coder(df_cia['Country'])
df_cia = df_cia.dropna(subset='iso3')
df_cia['year'] =df_cia['Date of Information'].str[:4]
df_cia = df_cia[['iso3', 'year', 'Country', 'gini']]
df_cia['year'] = pd.to_datetime(df_cia['year'], format='%Y')
df_cia = df_cia.set_index(['iso3', 'year'])
df_cia
# Out:
# /tmp/ipykernel_2199/25053258.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cia['year'] =df_cia['Date of Information'].str[:4]
# 0                                 Country  gini
# iso3 year
# ZAF  2014-01-01              South Africa  63.0
# NAM  2015-01-01                   Namibia  59.1
# ZMB  2015-01-01                    Zambia  57.1
# CAF  2008-01-01  Central African Republic  56.2
# SWZ  2016-01-01                  Eswatini  54.6
# ...                                   ...   ...
# ARM  2020-01-01                   Armenia  25.2
# SVK  2016-01-01                  Slovakia  25.2
# BLR  2020-01-01                   Belarus  24.4
# SVN  2017-01-01                  Slovenia  24.2
# FRO  2013-01-01             Faroe Islands  22.7
#
# [173 rows x 2 columns]

# %%
df_wb.isna().sum()
# Out:
# country             0
# gnipc            1073
# mat_deaths       3059
# suicide_rate     3284
# gini             5137
# fem_pop             0
# femicide_rate    4405
# suicide_count    3284
# dtype: int64

# %%
df_wb
# Out:
#                      country   gnipc  mat_deaths  suicide_rate  gini  fem_pop  \
# iso3 year
# ZWE  2021-01-01     Zimbabwe  1530.0         NaN           NaN   NaN  8449834
#      2020-01-01     Zimbabwe  1460.0      1700.0           NaN   NaN  8284447
#      2019-01-01     Zimbabwe  1450.0      1900.0           8.8  50.3  8122618
#      2018-01-01     Zimbabwe  1550.0      1700.0           8.7   NaN  7966181
#      2017-01-01     Zimbabwe  1170.0      1800.0           9.6  44.3  7810471
# ...                      ...     ...         ...           ...   ...      ...
# AFG  1994-01-01  Afghanistan     NaN         NaN           NaN   NaN  7722096
#      1993-01-01  Afghanistan     NaN         NaN           NaN   NaN  7000119
#      1992-01-01  Afghanistan     NaN         NaN           NaN   NaN  6028939
#      1991-01-01  Afghanistan     NaN         NaN           NaN   NaN  5372208
#      1990-01-01  Afghanistan     NaN         NaN           NaN   NaN  5346409
#
#                  femicide_rate  suicide_count
# iso3 year
# ZWE  2021-01-01       1.869859            NaN
#      2020-01-01       1.762339            NaN
#      2019-01-01       2.055987          715.0
#      2018-01-01       2.046150          693.0
#      2017-01-01            NaN          750.0
# ...                        ...            ...
# AFG  1994-01-01            NaN            NaN
#      1993-01-01            NaN            NaN
#      1992-01-01            NaN            NaN
#      1991-01-01            NaN            NaN
#      1990-01-01            NaN            NaN
#
# [6944 rows x 8 columns]

# %% [markdown]
# ### Fills in any empty cells in wb dataset with values from cia dataset ~17 extra countries. gini column set back to float

# %%
df_wb['gini'] = df_wb['gini'].fillna(df_cia['gini'])

df_wb = df_wb.sort_index()

df_wb['gini'] =df_wb['gini'].astype('float64')

df_wb
# Out:
#                   country    gnipc  mat_deaths  suicide_rate  gini  fem_pop  \
# iso3 year
# ABW  1990-01-01     Aruba  11570.0         NaN           NaN   NaN    33480
#      1991-01-01     Aruba  12560.0         NaN           NaN   NaN    34657
#      1992-01-01     Aruba  13610.0         NaN           NaN   NaN    35941
#      1993-01-01     Aruba  14640.0         NaN           NaN   NaN    37137
#      1994-01-01     Aruba  16060.0         NaN           NaN   NaN    38437
# ...                   ...      ...         ...           ...   ...      ...
# ZWE  2017-01-01  Zimbabwe   1170.0      1800.0           9.6  44.3  7810471
#      2018-01-01  Zimbabwe   1550.0      1700.0           8.7   NaN  7966181
#      2019-01-01  Zimbabwe   1450.0      1900.0           8.8  50.3  8122618
#      2020-01-01  Zimbabwe   1460.0      1700.0           NaN   NaN  8284447
#      2021-01-01  Zimbabwe   1530.0         NaN           NaN   NaN  8449834
#
#                  femicide_rate  suicide_count
# iso3 year
# ABW  1990-01-01       0.000000            NaN
#      1991-01-01            NaN            NaN
#      1992-01-01            NaN            NaN
#      1993-01-01            NaN            NaN
#      1994-01-01            NaN            NaN
# ...                        ...            ...
# ZWE  2017-01-01            NaN          750.0
#      2018-01-01       2.046150          693.0
#      2019-01-01       2.055987          715.0
#      2020-01-01       1.762339            NaN
#      2021-01-01       1.869859            NaN
#
# [6944 rows x 8 columns]

# %%
df_wb.isna().sum()
# Out:
# country             0
# gnipc            1073
# mat_deaths       3059
# suicide_rate     3284
# gini             5119
# fem_pop             0
# femicide_rate    4405
# suicide_count    3284
# dtype: int64

# %% [markdown]
# # Merging

# %% [markdown]
# ### The dichotamised economic dataframe is merged with the femicide dataframe on the shared iso3 index

# %%
df_fem = df_fem.set_index(['iso3', 'year'])

# %%
df_fem.index.dtypes
# Out:
# iso3            object
# year    datetime64[ns]
# dtype: object

# %%
df = df_fem.merge(df_wb, how='left', left_index=True, right_index=True).rename(columns={'country_x' : 'country'}).drop(columns=['country_y'])
df = df.sort_index()
df
# Out:
#                   region       subregion   country               indicator  \
# iso3 year
# ABW  1990-01-01  America       Caribbean     Aruba  Homicide: # of victims
#      1995-01-01  America       Caribbean     Aruba  Homicide: # of victims
#      1999-01-01  America       Caribbean     Aruba  Homicide: # of victims
#      2001-01-01  America       Caribbean     Aruba  Homicide: # of victims
#      2002-01-01  America       Caribbean     Aruba  Homicide: # of victims
# ...                  ...             ...       ...                     ...
# ZWE  1990-01-01   Africa  Eastern Africa  Zimbabwe  Homicide: # of victims
#      2018-01-01   Africa  Eastern Africa  Zimbabwe  Homicide: # of victims
#      2019-01-01   Africa  Eastern Africa  Zimbabwe  Homicide: # of victims
#      2020-01-01   Africa  Eastern Africa  Zimbabwe  Homicide: # of victims
#      2021-01-01   Africa  Eastern Africa  Zimbabwe  Homicide: # of victims
#
#                 disaggregation  gender source   unit  femicide_count footnote  \
# iso3 year
# ABW  1990-01-01              -  Female     WB  Count             0.0      NaN
#      1995-01-01              -  Female     WB  Count             0.0      NaN
#      1999-01-01              -  Female     WB  Count             1.0      NaN
#      2001-01-01              -  Female     WB  Count             2.0      NaN
#      2002-01-01              -  Female     WB  Count             1.0      NaN
# ...                        ...     ...    ...    ...             ...      ...
# ZWE  1990-01-01              -  Female     WB  Count           183.0      NaN
#      2018-01-01              -  Female     WB  Count           163.0      NaN
#      2019-01-01              -  Female     WB  Count           167.0      NaN
#      2020-01-01              -  Female     WB  Count           146.0      NaN
#      2021-01-01              -  Female     WB  Count           158.0      NaN
#
#                    gnipc  mat_deaths  suicide_rate  gini    fem_pop  \
# iso3 year
# ABW  1990-01-01  11570.0         NaN           NaN   NaN    33480.0
#      1995-01-01  16930.0         NaN           NaN   NaN    39724.0
#      1999-01-01  18320.0         NaN           NaN   NaN    45050.0
#      2001-01-01  20510.0         NaN           NaN   NaN    47178.0
#      2002-01-01  19290.0         NaN           NaN   NaN    47831.0
# ...                  ...         ...           ...   ...        ...
# ZWE  1990-01-01    740.0         NaN           NaN   NaN  5247850.0
#      2018-01-01   1550.0      1700.0           8.7   NaN  7966181.0
#      2019-01-01   1450.0      1900.0           8.8  50.3  8122618.0
#      2020-01-01   1460.0      1700.0           NaN   NaN  8284447.0
#      2021-01-01   1530.0         NaN           NaN   NaN  8449834.0
#
#                  femicide_rate  suicide_count
# iso3 year
# ABW  1990-01-01       0.000000            NaN
#      1995-01-01       0.000000            NaN
#      1999-01-01       2.219731            NaN
#      2001-01-01       4.239264            NaN
#      2002-01-01       2.090672            NaN
# ...                        ...            ...
# ZWE  1990-01-01       3.487142            NaN
#      2018-01-01       2.046150          693.0
#      2019-01-01       2.055987          715.0
#      2020-01-01       1.762339            NaN
#      2021-01-01       1.869859            NaN
#
# [2598 rows x 17 columns]

# %%
df.isna().sum()
# Out:
# region               0
# subregion            0
# country              0
# indicator            0
# disaggregation       0
# gender               0
# source               0
# unit                 0
# femicide_count       0
# footnote          2598
# gnipc              230
# mat_deaths         760
# suicide_rate       892
# gini              1439
# fem_pop             52
# femicide_rate       59
# suicide_count      892
# dtype: int64

# %% [markdown]
# femicide count globally over time, suicide count
# maps of femicide rate with year slider
# mean femicide rate over decades, see biggest gains/losses
#
# regression time series regression analysis on femicide rate compared with other variables.
# logistic regression on action plans
#
# worldbank used in articles datasets
#
# report on how dataset was created, why we did analyses
